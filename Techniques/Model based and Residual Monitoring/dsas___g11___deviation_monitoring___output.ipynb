# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.cluster import DBSCAN
from scipy.spatial.distance import cdist
from xgboost import XGBRegressor
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
import os
import time
from datetime import datetime

# غیرفعال کردن هشدارهای غیرضروری
import warnings
warnings.filterwarnings('ignore')

# TensorFlow تنظیمات
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# ============================================================================
# بخش 1: تعریف توابع تحلیل - سری اول (بیرینگ - 5 تابع)
# ============================================================================

def analysis_bearing_1_xgboost_wide(file_path, output_filename):
    """تحلیل 1: XGBoost - Wide Format (بیرینگ)"""
    print(f"\n{'='*60}")
    print(f"🔄 [بیرینگ-1] XGBoost Wide")
    print(f"{'='*60}")
    
    all_features = ['AssetID_9358', 'AssetID_9359', 'AssetID_9360', 'AssetID_9361', 
                    'AssetID_9368', 'AssetID_9369', 'AssetID_9370', 'AssetID_9357',
                    'AssetID_9343', 'AssetID_9344', 'AssetID_9408']
    target_sensors = ['AssetID_9358', 'AssetID_9359', 'AssetID_9360', 'AssetID_9361']
    
    try:
        df_raw = pd.read_excel(file_path)
        print(f"✅ فایل اصلی خوانده شد. تعداد رکوردها: {len(df_raw):,}")
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False
    
    print("🔄 مرحله 1: پیش‌پردازش و حذف داده‌های پرت...")
    
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(df_raw[all_features])
    dbscan = DBSCAN(eps=0.5, min_samples=5)
    labels = dbscan.fit_predict(scaled_data)
    
    cluster_centers = {}
    for cluster_id in set(labels):
        if cluster_id != -1:
            cluster_centers[cluster_id] = scaled_data[labels == cluster_id].mean(axis=0)
    
    def calculate_distance(row_index):
        label = labels[row_index]
        point = scaled_data[row_index].reshape(1, -1)
        if label != -1:
            center = cluster_centers[label].reshape(1, -1)
            return cdist(point, center, metric='euclidean')[0][0]
        else:
            if not cluster_centers: return 0.0
            all_centers = np.array(list(cluster_centers.values()))
            return np.min(cdist(point, all_centers, metric='euclidean'))
    
    before_count = len(df_raw)
    df_raw['distance'] = [calculate_distance(i) for i in range(len(df_raw))]
    df_sorted = df_raw.sort_values(by='distance', ascending=False)
    num_to_remove = int(len(df_sorted)*0.10)
    df_cleaned = df_sorted.iloc[num_to_remove:].copy()
    after_count = len(df_cleaned)
    print(f"   حذف {before_count - after_count:,} ردیف به عنوان داده‌های پرت")
    
    df_cleaned['date'] = pd.to_datetime(df_cleaned['date'])
    df_cleaned = df_cleaned.sort_values(by='date')
    
    split_idx = int(len(df_cleaned) * 0.80)
    train_df = df_cleaned.iloc[:split_idx].copy()
    test_df = df_cleaned.iloc[split_idx:].copy()
    
    print(f"   داده‌های آموزش: {len(train_df):,} رکورد")
    print(f"   داده‌های تست: {len(test_df):,} رکورد")
    
    print("🔄 مرحله 2: یادگیری و پیش‌بینی برای تمام سنسورها...")
    
    for target in target_sensors:
        current_features = [f for f in all_features if f != target]
        X_train, y_train = train_df[current_features], train_df[target]
        X_test = test_df[current_features]
        
        model = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=5, random_state=42, verbosity=0)
        model.fit(X_train, y_train)
        
        column_name = f'predicted_{target.split("_")[1]}'
        test_df[column_name] = model.predict(X_test)
        
        mse = np.mean((test_df[target] - test_df[column_name]) ** 2)
        rmse = np.sqrt(mse)
        print(f"   ✅ {target}: RMSE = {rmse:.6f}")
    
    predicted_cols = [f'predicted_{t.split("_")[1]}' for t in target_sensors]
    final_columns_order = ['date'] + all_features + predicted_cols
    
    try:
        os.makedirs(os.path.dirname(output_filename), exist_ok=True)
        test_df[final_columns_order].to_excel(output_filename, index=False)
        print(f"✅ فایل ذخیره شد: {output_filename}")
        return True
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False


def analysis_bearing_2_xgboost_long(file_path, output_filename):
    """تحلیل 2: XGBoost - Long Format (بیرینگ)"""
    print(f"\n{'='*60}")
    print(f"🔄 [بیرینگ-2] XGBoost Long")
    print(f"{'='*60}")
    
    all_features = ['AssetID_9358', 'AssetID_9359', 'AssetID_9360', 'AssetID_9361', 
                    'AssetID_9368', 'AssetID_9369', 'AssetID_9370', 'AssetID_9357',
                    'AssetID_9343', 'AssetID_9344', 'AssetID_9408']
    target_sensors = ['AssetID_9358', 'AssetID_9359', 'AssetID_9360', 'AssetID_9361']
    
    try:
        df_raw = pd.read_excel(file_path)
        print(f"✅ فایل اصلی خوانده شد. تعداد رکوردها: {len(df_raw):,}")
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False
    
    print("🔄 مرحله 1: پیش‌پردازش و حذف داده‌های پرت...")
    
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(df_raw[all_features])
    dbscan = DBSCAN(eps=0.5, min_samples=5)
    labels = dbscan.fit_predict(scaled_data)
    
    cluster_centers = {i: scaled_data[labels == i].mean(axis=0) for i in set(labels) if i != -1}
    
    def calc_dist(idx):
        label = labels[idx]
        point = scaled_data[idx].reshape(1, -1)
        if label != -1:
            return cdist(point, cluster_centers[label].reshape(1, -1))[0][0]
        return np.min(cdist(point, np.array(list(cluster_centers.values())))) if cluster_centers else 0
    
    before_count = len(df_raw)
    df_raw['distance'] = [calc_dist(i) for i in range(len(df_raw))]
    df_cleaned = df_raw.sort_values(by='distance', ascending=False).iloc[int(len(df_raw)*0.1):].copy()
    after_count = len(df_cleaned)
    print(f"   حذف {before_count - after_count:,} ردیف به عنوان داده‌های پرت")
    
    df_cleaned['date'] = pd.to_datetime(df_cleaned['date'])
    df_cleaned = df_cleaned.sort_values(by='date')
    
    split_idx = int(len(df_cleaned) * 0.80)
    train_df = df_cleaned.iloc[:split_idx].copy()
    test_df = df_cleaned.iloc[split_idx:].copy()
    
    print(f"   داده‌های آموزش: {len(train_df):,} رکورد")
    print(f"   داده‌های تست: {len(test_df):,} رکورد")
    
    print("🔄 مرحله 2: یادگیری و پیش‌بینی برای تمام سنسورها...")
    
    for target in target_sensors:
        features = [f for f in all_features if f != target]
        X_train, y_train = train_df[features], train_df[target]
        
        model = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=5, random_state=42, verbosity=0)
        model.fit(X_train, y_train)
        
        test_df[f'PRED_{target}'] = model.predict(test_df[features])
        
        mse = np.mean((test_df[target] - test_df[f'PRED_{target}']) ** 2)
        rmse = np.sqrt(mse)
        print(f"   ✅ {target}: RMSE = {rmse:.6f}")
    
    print("🔄 مرحله 3: تغییر ساختار داده به فرمت Long...")
    
    melted_actual = test_df.melt(id_vars=['date'], value_vars=target_sensors, 
                                 var_name='AssetID', value_name='actual')
    
    pred_cols = [f'PRED_{t}' for t in target_sensors]
    melted_pred = test_df.melt(id_vars=['date'], value_vars=pred_cols, 
                               var_name='temp_target', value_name='predicted')
    melted_pred['AssetID'] = melted_pred['temp_target'].str.replace('PRED_', '')
    
    final_long_df = pd.merge(melted_actual, melted_pred[['date', 'AssetID', 'predicted']], 
                             on=['date', 'AssetID'])
    final_long_df['error'] = final_long_df['actual'] - final_long_df['predicted']
    final_long_df['abs_error'] = np.abs(final_long_df['error'])
    
    print(f"   ✅ تعداد رکوردهای نهایی: {len(final_long_df):,}")
    
    try:
        os.makedirs(os.path.dirname(output_filename), exist_ok=True)
        final_long_df.to_excel(output_filename, index=False)
        print(f"✅ فایل ذخیره شد: {output_filename}")
        return True
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False


def analysis_bearing_3_xgboost_refined(file_path, output_filename):
    """تحلیل 3: XGBoost + DBSCAN Refined (بیرینگ)"""
    print(f"\n{'='*60}")
    print(f"🔄 [بیرینگ-3] XGBoost Refined")
    print(f"{'='*60}")
    
    all_sensors = ['AssetID_9357', 'AssetID_9343', 'AssetID_9358', 'AssetID_9359', 
                   'AssetID_9360', 'AssetID_9361', 'AssetID_9368', 'AssetID_9369', 'AssetID_9370']
    
    try:
        df_raw = pd.read_excel(file_path)
        df_raw['date'] = pd.to_datetime(df_raw['date'])
        df_raw = df_raw.sort_values(by='date')
        print(f"✅ فایل اصلی خوانده شد. تعداد رکوردها: {len(df_raw):,}")
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False
    
    print("🔄 مرحله 1: جداسازی داده‌های آموزشی و تست...")
    
    last_date = df_raw['date'].max()
    split_date = last_date - pd.Timedelta(days=20)
    raw_train_set = df_raw[df_raw['date'] <= split_date].copy()
    test_set = df_raw[df_raw['date'] > split_date].copy()
    
    print(f"   داده‌های آموزشی: {len(raw_train_set):,} رکورد")
    print(f"   داده‌های تست: {len(test_set):,} رکورد")
    
    print("🔄 مرحله 2: پالایش داده‌های آموزشی با DBSCAN...")
    
    scaler = StandardScaler()
    scaled_train = scaler.fit_transform(raw_train_set[all_sensors])
    
    dbscan = DBSCAN(eps=0.8, min_samples=10)
    labels = dbscan.fit_predict(scaled_train)
    
    normal_train_set = raw_train_set[labels != -1].copy()
    print(f"   داده‌های سالم تایید شده: {len(normal_train_set):,} رکورد")
    print(f"   داده‌های پرت حذف شده: {len(raw_train_set) - len(normal_train_set):,} ردیف")
    
    print("🔄 مرحله 3: آموزش مدل‌های XGBoost...")
    
    models = {}
    for target in all_sensors:
        features = [s for s in all_sensors if s != target]
        model = XGBRegressor(n_estimators=100, learning_rate=0.05, max_depth=5, random_state=42, verbosity=0)
        model.fit(normal_train_set[features], normal_train_set[target])
        models[target] = model
        print(f"   ✅ مدل برای {target} آموزش داده شد")
    
    print("🔄 مرحله 4: پایش انحراف در داده‌های تست...")
    
    all_errors = pd.DataFrame(index=test_set.index)
    for target in all_sensors:
        features = [s for s in all_sensors if s != target]
        preds = models[target].predict(test_set[features])
        all_errors[f'err_{target}'] = np.abs(test_set[target] - preds)
    
    test_set['System_Deviation_Index'] = all_errors.mean(axis=1)
    
    train_preds_all = []
    for target in all_sensors:
        features = [s for s in all_sensors if s != target]
        train_preds = models[target].predict(normal_train_set[features])
        train_preds_all.append(np.abs(normal_train_set[target] - train_preds))
    
    mean_train_error = np.mean(train_preds_all)
    std_train_error = np.std(train_preds_all)
    threshold = mean_train_error + (3*std_train_error)
    
    test_set['Is_Anomaly'] = test_set['System_Deviation_Index'] > threshold
    test_set['Anomaly_Label'] = test_set['Is_Anomaly'].map({True: '⚠️ Anomaly', False: '✅ Normal'})
    
    anomaly_count = test_set['Is_Anomaly'].sum()
    print(f"\n📊 تعداد ناهنجاری‌ها: {anomaly_count:,} ({anomaly_count/len(test_set)*100:.2f}%)")
    
    try:
        os.makedirs(os.path.dirname(output_filename), exist_ok=True)
        test_set.to_excel(output_filename, index=False)
        print(f"✅ فایل ذخیره شد: {output_filename}")
        return True
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False


def analysis_bearing_4_autoencoder_basic(file_path, output_filename):
    """تحلیل 4: Autoencoder - Basic (بیرینگ)"""
    print(f"\n{'='*60}")
    print(f"🔄 [بیرینگ-4] Autoencoder Basic")
    print(f"{'='*60}")
    
    all_sensors = ['AssetID_9357', 'AssetID_9343', 'AssetID_9358', 'AssetID_9359', 
                   'AssetID_9360', 'AssetID_9361', 'AssetID_9368', 'AssetID_9369', 'AssetID_9370']
    
    try:
        df = pd.read_excel(file_path)
        df['date'] = pd.to_datetime(df['date'])
        df = df.sort_values(by='date')
        print(f"✅ فایل اصلی خوانده شد. تعداد رکوردها: {len(df):,}")
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False
    
    df_clean = df.dropna(subset=all_sensors).copy()
    raw_data = df_clean[all_sensors].values
    print(f"📊 تعداد رکوردهای بدون داده خالی: {len(df_clean):,}")
    
    print("🔄 مرحله 1: نرمال‌سازی داده‌ها...")
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(raw_data)
    print(f"   ✅ نرمال‌سازی با {len(all_sensors)} سنسور انجام شد")
    
    print("🔄 مرحله 2: ساخت و آموزش مدل Autoencoder...")
    
    input_dim = len(all_sensors)
    input_layer = Input(shape=(input_dim,))
    encoded = Dense(16, activation='relu')(input_layer)
    latent_space = Dense(8, activation='relu')(encoded)
    decoded = Dense(16, activation='relu')(latent_space)
    output_layer = Dense(input_dim, activation='sigmoid')(decoded)
    
    autoencoder = Model(inputs=input_layer, outputs=output_layer)
    autoencoder.compile(optimizer=Adam(learning_rate=0.01), loss='mse')
    
    print("   🚀 در حال یادگیری رفتار سیستم...")
    autoencoder.fit(scaled_data, scaled_data, epochs=150, batch_size=32, shuffle=True, verbose=0)
    print("   ✅ آموزش مدل با موفقیت انجام شد")
    
    print("🔄 مرحله 3: محاسبه خطای بازسازی...")
    reconstructed_data = autoencoder.predict(scaled_data, verbose=0)
    mse_errors = np.mean(np.power(scaled_data - reconstructed_data, 2), axis=1)
    
    threshold = np.mean(mse_errors) + (3*np.std(mse_errors))
    print(f"   ✅ آستانه ناهنجاری: {threshold:.6f}")
    
    df_clean['Systematic_Deviation_Index'] = mse_errors
    df_clean['Anomaly_Threshold'] = threshold
    df_clean['Is_Anomaly'] = df_clean['Systematic_Deviation_Index'] > threshold
    df_clean['Anomaly_Label'] = df_clean['Is_Anomaly'].map({True: '⚠️ Anomaly', False: '✅ Normal'})
    
    print("🔄 مرحله 4: فیلتر کردن داده‌های یک ماه اخیر...")
    
    last_date = df_clean['date'].max()
    start_of_last_month = last_date - pd.Timedelta(days=30)
    df_last_month = df_clean[df_clean['date'] >= start_of_last_month].copy()
    
    print(f"   تعداد رکوردهای ماه اخیر: {len(df_last_month):,}")
    print(f"   تعداد ناهنجاری: {df_last_month['Is_Anomaly'].sum():,}")
    
    try:
        os.makedirs(os.path.dirname(output_filename), exist_ok=True)
        df_last_month.to_excel(output_filename, index=False)
        print(f"✅ فایل ذخیره شد: {output_filename}")
        return True
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False


def analysis_bearing_5_autoencoder_advanced(file_path, output_filename):
    """تحلیل 5: Autoencoder + EWMA + Dynamic Thresholds (بیرینگ)"""
    print(f"\n{'='*60}")
    print(f"🔄 [بیرینگ-5] Autoencoder Advanced")
    print(f"{'='*60}")
    
    all_features = ['AssetID_9357', 'AssetID_9343', 'AssetID_9358', 'AssetID_9359', 
                    'AssetID_9360', 'AssetID_9361', 'AssetID_9368', 'AssetID_9369', 'AssetID_9370']
    
    try:
        df = pd.read_excel(file_path)
        df['date'] = pd.to_datetime(df['date'])
        df = df.sort_values(by='date')
        print(f"✅ فایل اصلی خوانده شد. تعداد رکوردها: {len(df):,}")
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False
    
    df_clean = df.dropna(subset=all_features).copy()
    raw_data = df_clean[all_features].values
    print(f"📊 تعداد رکوردهای بدون داده خالی: {len(df_clean):,}")
    
    print("🔄 مرحله 1: نرمال‌سازی داده‌ها...")
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(raw_data)
    print(f"   ✅ نرمال‌سازی با {len(all_features)} سنسور انجام شد")
    
    print("🔄 مرحله 2: ساخت و آموزش مدل Autoencoder...")
    
    input_dim = len(all_features)
    input_layer = Input(shape=(input_dim,))
    encoded = Dense(16, activation='relu')(input_layer)
    latent = Dense(8, activation='relu')(encoded)
    decoded = Dense(16, activation='relu')(latent)
    output_layer = Dense(input_dim, activation='sigmoid')(decoded)
    
    autoencoder = Model(inputs=input_layer, outputs=output_layer)
    autoencoder.compile(optimizer=Adam(learning_rate=0.01), loss='mse')
    
    print("   🚀 یادگیری رفتار سیستماتیک سنسورها...")
    autoencoder.fit(scaled_data, scaled_data, epochs=150, batch_size=32, shuffle=True, verbose=0)
    print("   ✅ آموزش مدل با موفقیت انجام شد")
    
    print("🔄 مرحله 3: محاسبه شاخص‌های انحراف...")
    
    reconstructed = autoencoder.predict(scaled_data, verbose=0)
    mse_errors = np.mean(np.power(scaled_data - reconstructed, 2), axis=1)
    df_clean['Raw_Anomaly_Index'] = mse_errors
    
    print("🔄 مرحله 4: ارزیابی پیشرفته باقیمانده‌ها...")
    
    df_clean['Smooth_Deviation_Index'] = df_clean['Raw_Anomaly_Index'].ewm(alpha=0.1).mean()
    
    p95_threshold = df_clean['Smooth_Deviation_Index'].quantile(0.95)
    p99_threshold = df_clean['Smooth_Deviation_Index'].quantile(0.99)
    
    print(f"   📈 آستانه هشدار (زرد): {p95_threshold:.6f}")
    print(f"   🚫 آستانه بحرانی (قرمز): {p99_threshold:.6f}")
    
    def final_judgment(val):
        if val > p99_threshold:
            return "Critical (Red) - Systematic Failure"
        elif val > p95_threshold:
            return "Warning (Yellow) - Operational Drift"
        else:
            return "Normal (Green)"
    
    df_clean['Final_Status'] = df_clean['Smooth_Deviation_Index'].apply(final_judgment)
    
    print("🔄 مرحله 5: فیلتر کردن داده‌های یک ماه اخیر...")
    
    last_date = df_clean['date'].max()
    start_of_last_month = last_date - pd.Timedelta(days=30)
    df_output = df_clean[df_clean['date'] >= start_of_last_month].copy()
    
    print(f"   تعداد رکوردهای ماه اخیر: {len(df_output):,}")
    
    try:
        os.makedirs(os.path.dirname(output_filename), exist_ok=True)
        df_output.to_excel(output_filename, index=False)
        print(f"✅ فایل ذخیره شد: {output_filename}")
        return True
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False


# ============================================================================
# بخش 2: تعریف توابع تحلیل - سری دوم (ژنراتور - 5 تابع)
# ============================================================================

def analysis_generator_1_xgboost_wide(file_path, output_filename):
    """تحلیل 1: XGBoost - Wide Format (ژنراتور)"""
    print(f"\n{'='*60}")
    print(f"🔄 [ژنراتور-1] XGBoost Wide")
    print(f"{'='*60}")
    
    all_features = ['AssetID_9362', 'AssetID_9363', 'AssetID_9364', 'AssetID_9365', 
                    'AssetID_9366', 'AssetID_9367', 'AssetID_9371', 'AssetID_9372', 'AssetID_9373']
    target_sensors = all_features
    
    try:
        df_raw = pd.read_excel(file_path)
        print(f"✅ فایل اصلی خوانده شد. تعداد رکوردها: {len(df_raw):,}")
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False
    
    print("🔄 مرحله 1: پیش‌پردازش و حذف داده‌های پرت...")
    
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(df_raw[all_features])
    dbscan = DBSCAN(eps=0.5, min_samples=5)
    labels = dbscan.fit_predict(scaled_data)
    
    cluster_centers = {}
    for cluster_id in set(labels):
        if cluster_id != -1:
            cluster_centers[cluster_id] = scaled_data[labels == cluster_id].mean(axis=0)
    
    def calculate_distance(row_index):
        label = labels[row_index]
        point = scaled_data[row_index].reshape(1, -1)
        if label != -1:
            center = cluster_centers[label].reshape(1, -1)
            return cdist(point, center, metric='euclidean')[0][0]
        else:
            if not cluster_centers: return 0.0
            all_centers = np.array(list(cluster_centers.values()))
            return np.min(cdist(point, all_centers, metric='euclidean'))
    
    before_count = len(df_raw)
    df_raw['distance'] = [calculate_distance(i) for i in range(len(df_raw))]
    df_sorted = df_raw.sort_values(by='distance', ascending=False)
    num_to_remove = int(len(df_sorted)*0.10)
    df_cleaned = df_sorted.iloc[num_to_remove:].copy()
    after_count = len(df_cleaned)
    print(f"   حذف {before_count - after_count:,} ردیف به عنوان داده‌های پرت")
    
    df_cleaned['date'] = pd.to_datetime(df_cleaned['date'])
    df_cleaned = df_cleaned.sort_values(by='date')
    
    split_idx = int(len(df_cleaned) * 0.80)
    train_df = df_cleaned.iloc[:split_idx].copy()
    test_df = df_cleaned.iloc[split_idx:].copy()
    
    print(f"   داده‌های آموزش: {len(train_df):,} رکورد")
    print(f"   داده‌های تست: {len(test_df):,} رکورد")
    
    print("🔄 مرحله 2: یادگیری و پیش‌بینی برای تمام سنسورها...")
    
    for target in target_sensors:
        current_features = [f for f in all_features if f != target]
        X_train, y_train = train_df[current_features], train_df[target]
        X_test = test_df[current_features]
        
        model = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=5, random_state=42, verbosity=0)
        model.fit(X_train, y_train)
        
        column_name = f'predicted_{target.split("_")[1]}'
        test_df[column_name] = model.predict(X_test)
        
        mse = np.mean((test_df[target] - test_df[column_name]) ** 2)
        rmse = np.sqrt(mse)
        print(f"   ✅ {target}: RMSE = {rmse:.6f}")
    
    predicted_cols = [f'predicted_{t.split("_")[1]}' for t in target_sensors]
    final_columns_order = ['date'] + all_features + predicted_cols
    
    try:
        os.makedirs(os.path.dirname(output_filename), exist_ok=True)
        test_df[final_columns_order].to_excel(output_filename, index=False)
        print(f"✅ فایل ذخیره شد: {output_filename}")
        return True
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False


def analysis_generator_2_xgboost_long(file_path, output_filename):
    """تحلیل 2: XGBoost - Long Format (ژنراتور)"""
    print(f"\n{'='*60}")
    print(f"🔄 [ژنراتور-2] XGBoost Long")
    print(f"{'='*60}")
    
    all_features = ['AssetID_9362', 'AssetID_9363', 'AssetID_9364', 'AssetID_9365', 
                    'AssetID_9366', 'AssetID_9367', 'AssetID_9371', 'AssetID_9372', 'AssetID_9373']
    target_sensors = all_features
    
    try:
        df_raw = pd.read_excel(file_path)
        print(f"✅ فایل اصلی خوانده شد. تعداد رکوردها: {len(df_raw):,}")
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False
    
    print("🔄 مرحله 1: پیش‌پردازش و حذف داده‌های پرت...")
    
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(df_raw[all_features])
    dbscan = DBSCAN(eps=0.5, min_samples=5)
    labels = dbscan.fit_predict(scaled_data)
    
    cluster_centers = {i: scaled_data[labels == i].mean(axis=0) for i in set(labels) if i != -1}
    
    def calc_dist(idx):
        label = labels[idx]
        point = scaled_data[idx].reshape(1, -1)
        if label != -1:
            return cdist(point, cluster_centers[label].reshape(1, -1))[0][0]
        return np.min(cdist(point, np.array(list(cluster_centers.values())))) if cluster_centers else 0
    
    before_count = len(df_raw)
    df_raw['distance'] = [calc_dist(i) for i in range(len(df_raw))]
    df_cleaned = df_raw.sort_values(by='distance', ascending=False).iloc[int(len(df_raw)*0.1):].copy()
    after_count = len(df_cleaned)
    print(f"   حذف {before_count - after_count:,} ردیف به عنوان داده‌های پرت")
    
    df_cleaned['date'] = pd.to_datetime(df_cleaned['date'])
    df_cleaned = df_cleaned.sort_values(by='date')
    
    split_idx = int(len(df_cleaned) * 0.80)
    train_df = df_cleaned.iloc[:split_idx].copy()
    test_df = df_cleaned.iloc[split_idx:].copy()
    
    print(f"   داده‌های آموزش: {len(train_df):,} رکورد")
    print(f"   داده‌های تست: {len(test_df):,} رکورد")
    
    print("🔄 مرحله 2: یادگیری و پیش‌بینی برای تمام سنسورها...")
    
    for target in target_sensors:
        features = [f for f in all_features if f != target]
        X_train, y_train = train_df[features], train_df[target]
        
        model = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=5, random_state=42, verbosity=0)
        model.fit(X_train, y_train)
        
        test_df[f'PRED_{target}'] = model.predict(test_df[features])
        
        mse = np.mean((test_df[target] - test_df[f'PRED_{target}']) ** 2)
        rmse = np.sqrt(mse)
        print(f"   ✅ {target}: RMSE = {rmse:.6f}")
    
    print("🔄 مرحله 3: تغییر ساختار داده به فرمت Long...")
    
    melted_actual = test_df.melt(id_vars=['date'], value_vars=target_sensors, 
                                 var_name='AssetID', value_name='actual')
    
    pred_cols = [f'PRED_{t}' for t in target_sensors]
    melted_pred = test_df.melt(id_vars=['date'], value_vars=pred_cols, 
                               var_name='temp_target', value_name='predicted')
    melted_pred['AssetID'] = melted_pred['temp_target'].str.replace('PRED_', '')
    
    final_long_df = pd.merge(melted_actual, melted_pred[['date', 'AssetID', 'predicted']], 
                             on=['date', 'AssetID'])
    final_long_df['error'] = final_long_df['actual'] - final_long_df['predicted']
    final_long_df['abs_error'] = np.abs(final_long_df['error'])
    
    print(f"   ✅ تعداد رکوردهای نهایی: {len(final_long_df):,}")
    
    try:
        os.makedirs(os.path.dirname(output_filename), exist_ok=True)
        final_long_df.to_excel(output_filename, index=False)
        print(f"✅ فایل ذخیره شد: {output_filename}")
        return True
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False


def analysis_generator_3_xgboost_refined(file_path, output_filename):
    """تحلیل 3: XGBoost + DBSCAN Refined (ژنراتور)"""
    print(f"\n{'='*60}")
    print(f"🔄 [ژنراتور-3] XGBoost Refined")
    print(f"{'='*60}")
    
    all_features = ['AssetID_9362', 'AssetID_9363', 'AssetID_9364', 'AssetID_9365', 
                    'AssetID_9366', 'AssetID_9367', 'AssetID_9371', 'AssetID_9372', 'AssetID_9373']
    
    try:
        df_raw = pd.read_excel(file_path)
        df_raw['date'] = pd.to_datetime(df_raw['date'])
        df_raw = df_raw.sort_values(by='date')
        print(f"✅ فایل اصلی خوانده شد. تعداد رکوردها: {len(df_raw):,}")
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False
    
    print("🔄 مرحله 1: جداسازی داده‌های آموزشی و تست...")
    
    last_date = df_raw['date'].max()
    split_date = last_date - pd.Timedelta(days=20)
    raw_train_set = df_raw[df_raw['date'] <= split_date].copy()
    test_set = df_raw[df_raw['date'] > split_date].copy()
    
    print(f"   داده‌های آموزشی: {len(raw_train_set):,} رکورد")
    print(f"   داده‌های تست: {len(test_set):,} رکورد")
    
    print("🔄 مرحله 2: پالایش داده‌های آموزشی با DBSCAN...")
    
    scaler = StandardScaler()
    scaled_train = scaler.fit_transform(raw_train_set[all_features])
    
    dbscan = DBSCAN(eps=0.8, min_samples=10)
    labels = dbscan.fit_predict(scaled_train)
    
    normal_train_set = raw_train_set[labels != -1].copy()
    print(f"   داده‌های سالم تایید شده: {len(normal_train_set):,} رکورد")
    print(f"   داده‌های پرت حذف شده: {len(raw_train_set) - len(normal_train_set):,} ردیف")
    
    print("🔄 مرحله 3: آموزش مدل‌های XGBoost...")
    
    models = {}
    for target in all_features:
        features = [s for s in all_features if s != target]
        model = XGBRegressor(n_estimators=100, learning_rate=0.05, max_depth=5, random_state=42, verbosity=0)
        model.fit(normal_train_set[features], normal_train_set[target])
        models[target] = model
        print(f"   ✅ مدل برای {target} آموزش داده شد")
    
    print("🔄 مرحله 4: پایش انحراف در داده‌های تست...")
    
    all_errors = pd.DataFrame(index=test_set.index)
    for target in all_features:
        features = [s for s in all_features if s != target]
        preds = models[target].predict(test_set[features])
        all_errors[f'err_{target}'] = np.abs(test_set[target] - preds)
    
    test_set['System_Deviation_Index'] = all_errors.mean(axis=1)
    
    train_preds_all = []
    for target in all_features:
        features = [s for s in all_features if s != target]
        train_preds = models[target].predict(normal_train_set[features])
        train_preds_all.append(np.abs(normal_train_set[target] - train_preds))
    
    mean_train_error = np.mean(train_preds_all)
    std_train_error = np.std(train_preds_all)
    threshold = mean_train_error + (3*std_train_error)
    
    test_set['Is_Anomaly'] = test_set['System_Deviation_Index'] > threshold
    test_set['Anomaly_Label'] = test_set['Is_Anomaly'].map({True: '⚠️ Anomaly', False: '✅ Normal'})
    
    anomaly_count = test_set['Is_Anomaly'].sum()
    print(f"\n📊 تعداد ناهنجاری‌ها: {anomaly_count:,} ({anomaly_count/len(test_set)*100:.2f}%)")
    
    try:
        os.makedirs(os.path.dirname(output_filename), exist_ok=True)
        test_set.to_excel(output_filename, index=False)
        print(f"✅ فایل ذخیره شد: {output_filename}")
        return True
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False


def analysis_generator_4_autoencoder_basic(file_path, output_filename):
    """تحلیل 4: Autoencoder - Basic (ژنراتور)"""
    print(f"\n{'='*60}")
    print(f"🔄 [ژنراتور-4] Autoencoder Basic")
    print(f"{'='*60}")
    
    all_features = ['AssetID_9362', 'AssetID_9363', 'AssetID_9364', 'AssetID_9365', 
                    'AssetID_9366', 'AssetID_9367', 'AssetID_9371', 'AssetID_9372', 'AssetID_9373']
    
    try:
        df = pd.read_excel(file_path)
        df['date'] = pd.to_datetime(df['date'])
        df = df.sort_values(by='date')
        print(f"✅ فایل اصلی خوانده شد. تعداد رکوردها: {len(df):,}")
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False
    
    df_clean = df.dropna(subset=all_features).copy()
    raw_data = df_clean[all_features].values
    print(f"📊 تعداد رکوردهای بدون داده خالی: {len(df_clean):,}")
    
    print("🔄 مرحله 1: نرمال‌سازی داده‌ها...")
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(raw_data)
    print(f"   ✅ نرمال‌سازی با {len(all_features)} سنسور انجام شد")
    
    print("🔄 مرحله 2: ساخت و آموزش مدل Autoencoder...")
    
    input_dim = len(all_features)
    input_layer = Input(shape=(input_dim,))
    encoded = Dense(16, activation='relu')(input_layer)
    latent_space = Dense(8, activation='relu')(encoded)
    decoded = Dense(16, activation='relu')(latent_space)
    output_layer = Dense(input_dim, activation='sigmoid')(decoded)
    
    autoencoder = Model(inputs=input_layer, outputs=output_layer)
    autoencoder.compile(optimizer=Adam(learning_rate=0.01), loss='mse')
    
    print("   🚀 در حال یادگیری رفتار سیستم...")
    autoencoder.fit(scaled_data, scaled_data, epochs=150, batch_size=32, shuffle=True, verbose=0)
    print("   ✅ آموزش مدل با موفقیت انجام شد")
    
    print("🔄 مرحله 3: محاسبه خطای بازسازی...")
    reconstructed_data = autoencoder.predict(scaled_data, verbose=0)
    mse_errors = np.mean(np.power(scaled_data - reconstructed_data, 2), axis=1)
    
    threshold = np.mean(mse_errors) + (3*np.std(mse_errors))
    print(f"   ✅ آستانه ناهنجاری: {threshold:.6f}")
    
    df_clean['Systematic_Deviation_Index'] = mse_errors
    df_clean['Anomaly_Threshold'] = threshold
    df_clean['Is_Anomaly'] = df_clean['Systematic_Deviation_Index'] > threshold
    df_clean['Anomaly_Label'] = df_clean['Is_Anomaly'].map({True: '⚠️ Anomaly', False: '✅ Normal'})
    
    print("🔄 مرحله 4: فیلتر کردن داده‌های یک ماه اخیر...")
    
    last_date = df_clean['date'].max()
    start_of_last_month = last_date - pd.Timedelta(days=30)
    df_last_month = df_clean[df_clean['date'] >= start_of_last_month].copy()
    
    print(f"   تعداد رکوردهای ماه اخیر: {len(df_last_month):,}")
    print(f"   تعداد ناهنجاری: {df_last_month['Is_Anomaly'].sum():,}")
    
    try:
        os.makedirs(os.path.dirname(output_filename), exist_ok=True)
        df_last_month.to_excel(output_filename, index=False)
        print(f"✅ فایل ذخیره شد: {output_filename}")
        return True
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False


def analysis_generator_5_autoencoder_advanced(file_path, output_filename):
    """تحلیل 5: Autoencoder + EWMA + Dynamic Thresholds (ژنراتور)"""
    print(f"\n{'='*60}")
    print(f"🔄 [ژنراتور-5] Autoencoder Advanced")
    print(f"{'='*60}")
    
    all_features = ['AssetID_9362', 'AssetID_9363', 'AssetID_9364', 'AssetID_9365', 
                    'AssetID_9366', 'AssetID_9367', 'AssetID_9371', 'AssetID_9372', 'AssetID_9373']
    
    try:
        df = pd.read_excel(file_path)
        df['date'] = pd.to_datetime(df['date'])
        df = df.sort_values(by='date')
        print(f"✅ فایل اصلی خوانده شد. تعداد رکوردها: {len(df):,}")
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False
    
    df_clean = df.dropna(subset=all_features).copy()
    raw_data = df_clean[all_features].values
    print(f"📊 تعداد رکوردهای بدون داده خالی: {len(df_clean):,}")
    
    print("🔄 مرحله 1: نرمال‌سازی داده‌ها...")
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(raw_data)
    print(f"   ✅ نرمال‌سازی با {len(all_features)} سنسور انجام شد")
    
    print("🔄 مرحله 2: ساخت و آموزش مدل Autoencoder...")
    
    input_dim = len(all_features)
    input_layer = Input(shape=(input_dim,))
    encoded = Dense(16, activation='relu')(input_layer)
    latent = Dense(8, activation='relu')(encoded)
    decoded = Dense(16, activation='relu')(latent)
    output_layer = Dense(input_dim, activation='sigmoid')(decoded)
    
    autoencoder = Model(inputs=input_layer, outputs=output_layer)
    autoencoder.compile(optimizer=Adam(learning_rate=0.01), loss='mse')
    
    print("   🚀 یادگیری رفتار سیستماتیک سنسورها...")
    autoencoder.fit(scaled_data, scaled_data, epochs=150, batch_size=32, shuffle=True, verbose=0)
    print("   ✅ آموزش مدل با موفقیت انجام شد")
    
    print("🔄 مرحله 3: محاسبه شاخص‌های انحراف...")
    
    reconstructed = autoencoder.predict(scaled_data, verbose=0)
    mse_errors = np.mean(np.power(scaled_data - reconstructed, 2), axis=1)
    df_clean['Raw_Anomaly_Index'] = mse_errors
    
    print("🔄 مرحله 4: ارزیابی پیشرفته باقیمانده‌ها...")
    
    df_clean['Smooth_Deviation_Index'] = df_clean['Raw_Anomaly_Index'].ewm(alpha=0.1).mean()
    
    p95_threshold = df_clean['Smooth_Deviation_Index'].quantile(0.95)
    p99_threshold = df_clean['Smooth_Deviation_Index'].quantile(0.99)
    
    print(f"   📈 آستانه هشدار (زرد): {p95_threshold:.6f}")
    print(f"   🚫 آستانه بحرانی (قرمز): {p99_threshold:.6f}")
    
    def final_judgment(val):
        if val > p99_threshold:
            return "Critical (Red) - Systematic Failure"
        elif val > p95_threshold:
            return "Warning (Yellow) - Operational Drift"
        else:
            return "Normal (Green)"
    
    df_clean['Final_Status'] = df_clean['Smooth_Deviation_Index'].apply(final_judgment)
    
    print("🔄 مرحله 5: فیلتر کردن داده‌های یک ماه اخیر...")
    
    last_date = df_clean['date'].max()
    start_of_last_month = last_date - pd.Timedelta(days=30)
    df_output = df_clean[df_clean['date'] >= start_of_last_month].copy()
    
    print(f"   تعداد رکوردهای ماه اخیر: {len(df_output):,}")
    
    try:
        os.makedirs(os.path.dirname(output_filename), exist_ok=True)
        df_output.to_excel(output_filename, index=False)
        print(f"✅ فایل ذخیره شد: {output_filename}")
        return True
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False


# ============================================================================
# بخش 3: تعریف توابع تحلیل - سری سوم (روغن‌کاری - 5 تابع)
# ============================================================================

def analysis_lubrication_1_xgboost_wide(file_path, output_filename):
    """تحلیل 1: XGBoost - Wide Format (روغن‌کاری)"""
    print(f"\n{'='*60}")
    print(f"🔄 [روغن‌کاری-1] XGBoost Wide")
    print(f"{'='*60}")
    
    all_features = ['AssetID_9343','AssetID_9375', 'AssetID_8341', 'AssetID_8342', 'AssetID_8343', 
                    'AssetID_8344', 'AssetID_8346', 'AssetID_9286', 'AssetID_9287']
    target_sensors = ['AssetID_9343','AssetID_9357','AssetID_9375', 'AssetID_8341', 'AssetID_8343', 
                      'AssetID_8344', 'AssetID_8346', 'AssetID_9286', 'AssetID_9287']
    
    try:
        df_raw = pd.read_excel(file_path)
        print(f"✅ فایل اصلی خوانده شد. تعداد رکوردها: {len(df_raw):,}")
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False
    
    print("🔄 مرحله 1: پیش‌پردازش و حذف داده‌های پرت...")
    
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(df_raw[all_features])
    dbscan = DBSCAN(eps=0.5, min_samples=5)
    labels = dbscan.fit_predict(scaled_data)
    
    cluster_centers = {}
    for cluster_id in set(labels):
        if cluster_id != -1:
            cluster_centers[cluster_id] = scaled_data[labels == cluster_id].mean(axis=0)
    
    def calculate_distance(row_index):
        label = labels[row_index]
        point = scaled_data[row_index].reshape(1, -1)
        if label != -1:
            center = cluster_centers[label].reshape(1, -1)
            return cdist(point, center, metric='euclidean')[0][0]
        else:
            if not cluster_centers: return 0.0
            all_centers = np.array(list(cluster_centers.values()))
            return np.min(cdist(point, all_centers, metric='euclidean'))
    
    before_count = len(df_raw)
    df_raw['distance'] = [calculate_distance(i) for i in range(len(df_raw))]
    df_sorted = df_raw.sort_values(by='distance', ascending=False)
    num_to_remove = int(len(df_sorted)*0.10)
    df_cleaned = df_sorted.iloc[num_to_remove:].copy()
    after_count = len(df_cleaned)
    print(f"   حذف {before_count - after_count:,} ردیف به عنوان داده‌های پرت")
    
    df_cleaned['date'] = pd.to_datetime(df_cleaned['date'])
    df_cleaned = df_cleaned.sort_values(by='date')
    
    split_idx = int(len(df_cleaned) * 0.80)
    train_df = df_cleaned.iloc[:split_idx].copy()
    test_df = df_cleaned.iloc[split_idx:].copy()
    
    print(f"   داده‌های آموزش: {len(train_df):,} رکورد")
    print(f"   داده‌های تست: {len(test_df):,} رکورد")
    
    print("🔄 مرحله 2: یادگیری و پیش‌بینی برای تمام سنسورها...")
    
    for target in target_sensors:
        current_features = [f for f in all_features if f != target]
        X_train, y_train = train_df[current_features], train_df[target]
        X_test = test_df[current_features]
        
        model = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=5, random_state=42, verbosity=0)
        model.fit(X_train, y_train)
        
        column_name = f'predicted_{target.split("_")[1]}'
        test_df[column_name] = model.predict(X_test)
        
        mse = np.mean((test_df[target] - test_df[column_name]) ** 2)
        rmse = np.sqrt(mse)
        print(f"   ✅ {target}: RMSE = {rmse:.6f}")
    
    predicted_cols = [f'predicted_{t.split("_")[1]}' for t in target_sensors]
    final_columns_order = ['date'] + all_features + predicted_cols
    
    try:
        os.makedirs(os.path.dirname(output_filename), exist_ok=True)
        test_df[final_columns_order].to_excel(output_filename, index=False)
        print(f"✅ فایل ذخیره شد: {output_filename}")
        return True
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False


def analysis_lubrication_2_xgboost_long(file_path, output_filename):
    """تحلیل 2: XGBoost - Long Format (روغن‌کاری)"""
    print(f"\n{'='*60}")
    print(f"🔄 [روغن‌کاری-2] XGBoost Long")
    print(f"{'='*60}")
    
    all_features = ['AssetID_9343','AssetID_9375', 'AssetID_8341', 'AssetID_8342', 'AssetID_8343', 
                    'AssetID_8344', 'AssetID_8346', 'AssetID_9286', 'AssetID_9287']
    target_sensors = ['AssetID_9343','AssetID_9357','AssetID_9375', 'AssetID_8341', 'AssetID_8343', 
                      'AssetID_8344', 'AssetID_8346', 'AssetID_9286', 'AssetID_9287']
    
    try:
        df_raw = pd.read_excel(file_path)
        print(f"✅ فایل اصلی خوانده شد. تعداد رکوردها: {len(df_raw):,}")
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False
    
    print("🔄 مرحله 1: پیش‌پردازش و حذف داده‌های پرت...")
    
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(df_raw[all_features])
    dbscan = DBSCAN(eps=0.5, min_samples=5)
    labels = dbscan.fit_predict(scaled_data)
    
    cluster_centers = {i: scaled_data[labels == i].mean(axis=0) for i in set(labels) if i != -1}
    
    def calc_dist(idx):
        label = labels[idx]
        point = scaled_data[idx].reshape(1, -1)
        if label != -1:
            return cdist(point, cluster_centers[label].reshape(1, -1))[0][0]
        return np.min(cdist(point, np.array(list(cluster_centers.values())))) if cluster_centers else 0
    
    before_count = len(df_raw)
    df_raw['distance'] = [calc_dist(i) for i in range(len(df_raw))]
    df_cleaned = df_raw.sort_values(by='distance', ascending=False).iloc[int(len(df_raw)*0.1):].copy()
    after_count = len(df_cleaned)
    print(f"   حذف {before_count - after_count:,} ردیف به عنوان داده‌های پرت")
    
    df_cleaned['date'] = pd.to_datetime(df_cleaned['date'])
    df_cleaned = df_cleaned.sort_values(by='date')
    
    split_idx = int(len(df_cleaned) * 0.80)
    train_df = df_cleaned.iloc[:split_idx].copy()
    test_df = df_cleaned.iloc[split_idx:].copy()
    
    print(f"   داده‌های آموزش: {len(train_df):,} رکورد")
    print(f"   داده‌های تست: {len(test_df):,} رکورد")
    
    print("🔄 مرحله 2: یادگیری و پیش‌بینی برای تمام سنسورها...")
    
    for target in target_sensors:
        features = [f for f in all_features if f != target]
        X_train, y_train = train_df[features], train_df[target]
        
        model = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=5, random_state=42, verbosity=0)
        model.fit(X_train, y_train)
        
        test_df[f'PRED_{target}'] = model.predict(test_df[features])
        
        mse = np.mean((test_df[target] - test_df[f'PRED_{target}']) ** 2)
        rmse = np.sqrt(mse)
        print(f"   ✅ {target}: RMSE = {rmse:.6f}")
    
    print("🔄 مرحله 3: تغییر ساختار داده به فرمت Long...")
    
    melted_actual = test_df.melt(id_vars=['date'], value_vars=target_sensors, 
                                 var_name='AssetID', value_name='actual')
    
    pred_cols = [f'PRED_{t}' for t in target_sensors]
    melted_pred = test_df.melt(id_vars=['date'], value_vars=pred_cols, 
                               var_name='temp_target', value_name='predicted')
    melted_pred['AssetID'] = melted_pred['temp_target'].str.replace('PRED_', '')
    
    final_long_df = pd.merge(melted_actual, melted_pred[['date', 'AssetID', 'predicted']], 
                             on=['date', 'AssetID'])
    final_long_df['error'] = final_long_df['actual'] - final_long_df['predicted']
    final_long_df['abs_error'] = np.abs(final_long_df['error'])
    
    print(f"   ✅ تعداد رکوردهای نهایی: {len(final_long_df):,}")
    
    try:
        os.makedirs(os.path.dirname(output_filename), exist_ok=True)
        final_long_df.to_excel(output_filename, index=False)
        print(f"✅ فایل ذخیره شد: {output_filename}")
        return True
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False


def analysis_lubrication_3_xgboost_refined(file_path, output_filename):
    """تحلیل 3: XGBoost + DBSCAN Refined (روغن‌کاری)"""
    print(f"\n{'='*60}")
    print(f"🔄 [روغن‌کاری-3] XGBoost Refined")
    print(f"{'='*60}")
    
    all_features = ['AssetID_9343','AssetID_9375', 'AssetID_8341', 'AssetID_8342', 'AssetID_8343', 
                    'AssetID_8344', 'AssetID_8346', 'AssetID_9286', 'AssetID_9287']
    target_sensors = ['AssetID_9343','AssetID_9357','AssetID_9375', 'AssetID_8341', 'AssetID_8343', 
                      'AssetID_8344', 'AssetID_8346', 'AssetID_9286', 'AssetID_9287']
    
    try:
        df_raw = pd.read_excel(file_path)
        df_raw['date'] = pd.to_datetime(df_raw['date'])
        df_raw = df_raw.sort_values(by='date')
        print(f"✅ فایل اصلی خوانده شد. تعداد رکوردها: {len(df_raw):,}")
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False
    
    print("🔄 مرحله 1: جداسازی داده‌های آموزشی و تست...")
    
    last_date = df_raw['date'].max()
    split_date = last_date - pd.Timedelta(days=20)
    raw_train_set = df_raw[df_raw['date'] <= split_date].copy()
    test_set = df_raw[df_raw['date'] > split_date].copy()
    
    print(f"   داده‌های آموزشی: {len(raw_train_set):,} رکورد")
    print(f"   داده‌های تست: {len(test_set):,} رکورد")
    
    print("🔄 مرحله 2: پالایش داده‌های آموزشی با DBSCAN...")
    
    scaler = StandardScaler()
    scaled_train = scaler.fit_transform(raw_train_set[all_features])
    
    dbscan = DBSCAN(eps=0.8, min_samples=10)
    labels = dbscan.fit_predict(scaled_train)
    
    normal_train_set = raw_train_set[labels != -1].copy()
    print(f"   داده‌های سالم تایید شده: {len(normal_train_set):,} رکورد")
    print(f"   داده‌های پرت حذف شده: {len(raw_train_set) - len(normal_train_set):,} ردیف")
    
    print("🔄 مرحله 3: آموزش مدل‌های XGBoost...")
    
    models = {}
    for target in all_features:
        features = [s for s in all_features if s != target]
        model = XGBRegressor(n_estimators=100, learning_rate=0.05, max_depth=5, random_state=42, verbosity=0)
        model.fit(normal_train_set[features], normal_train_set[target])
        models[target] = model
        print(f"   ✅ مدل برای {target} آموزش داده شد")
    
    print("🔄 مرحله 4: پایش انحراف در داده‌های تست...")
    
    all_errors = pd.DataFrame(index=test_set.index)
    for target in all_features:
        features = [s for s in all_features if s != target]
        preds = models[target].predict(test_set[features])
        all_errors[f'err_{target}'] = np.abs(test_set[target] - preds)
    
    test_set['System_Deviation_Index'] = all_errors.mean(axis=1)
    
    train_preds_all = []
    for target in all_features:
        features = [s for s in all_features if s != target]
        train_preds = models[target].predict(normal_train_set[features])
        train_preds_all.append(np.abs(normal_train_set[target] - train_preds))
    
    mean_train_error = np.mean(train_preds_all)
    std_train_error = np.std(train_preds_all)
    threshold = mean_train_error + (3*std_train_error)
    
    test_set['Is_Anomaly'] = test_set['System_Deviation_Index'] > threshold
    test_set['Anomaly_Label'] = test_set['Is_Anomaly'].map({True: '⚠️ Anomaly', False: '✅ Normal'})
    
    anomaly_count = test_set['Is_Anomaly'].sum()
    print(f"\n📊 تعداد ناهنجاری‌ها: {anomaly_count:,} ({anomaly_count/len(test_set)*100:.2f}%)")
    
    try:
        os.makedirs(os.path.dirname(output_filename), exist_ok=True)
        test_set.to_excel(output_filename, index=False)
        print(f"✅ فایل ذخیره شد: {output_filename}")
        return True
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False


def analysis_lubrication_4_autoencoder_basic(file_path, output_filename):
    """تحلیل 4: Autoencoder - Basic (روغن‌کاری)"""
    print(f"\n{'='*60}")
    print(f"🔄 [روغن‌کاری-4] Autoencoder Basic")
    print(f"{'='*60}")
    
    all_features = ['AssetID_9343','AssetID_9375', 'AssetID_8341', 'AssetID_8342', 'AssetID_8343', 
                    'AssetID_8344', 'AssetID_8346', 'AssetID_9286', 'AssetID_9287']
    
    try:
        df = pd.read_excel(file_path)
        df['date'] = pd.to_datetime(df['date'])
        df = df.sort_values(by='date')
        print(f"✅ فایل اصلی خوانده شد. تعداد رکوردها: {len(df):,}")
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False
    
    df_clean = df.dropna(subset=all_features).copy()
    raw_data = df_clean[all_features].values
    print(f"📊 تعداد رکوردهای بدون داده خالی: {len(df_clean):,}")
    
    print("🔄 مرحله 1: نرمال‌سازی داده‌ها...")
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(raw_data)
    print(f"   ✅ نرمال‌سازی با {len(all_features)} سنسور انجام شد")
    
    print("🔄 مرحله 2: ساخت و آموزش مدل Autoencoder...")
    
    input_dim = len(all_features)
    input_layer = Input(shape=(input_dim,))
    encoded = Dense(16, activation='relu')(input_layer)
    latent_space = Dense(8, activation='relu')(encoded)
    decoded = Dense(16, activation='relu')(latent_space)
    output_layer = Dense(input_dim, activation='sigmoid')(decoded)
    
    autoencoder = Model(inputs=input_layer, outputs=output_layer)
    autoencoder.compile(optimizer=Adam(learning_rate=0.01), loss='mse')
    
    print("   🚀 در حال یادگیری رفتار سیستم...")
    autoencoder.fit(scaled_data, scaled_data, epochs=150, batch_size=32, shuffle=True, verbose=0)
    print("   ✅ آموزش مدل با موفقیت انجام شد")
    
    print("🔄 مرحله 3: محاسبه خطای بازسازی...")
    reconstructed_data = autoencoder.predict(scaled_data, verbose=0)
    mse_errors = np.mean(np.power(scaled_data - reconstructed_data, 2), axis=1)
    
    threshold = np.mean(mse_errors) + (3*np.std(mse_errors))
    print(f"   ✅ آستانه ناهنجاری: {threshold:.6f}")
    
    df_clean['Systematic_Deviation_Index'] = mse_errors
    df_clean['Anomaly_Threshold'] = threshold
    df_clean['Is_Anomaly'] = df_clean['Systematic_Deviation_Index'] > threshold
    df_clean['Anomaly_Label'] = df_clean['Is_Anomaly'].map({True: '⚠️ Anomaly', False: '✅ Normal'})
    
    print("🔄 مرحله 4: فیلتر کردن داده‌های یک ماه اخیر...")
    
    last_date = df_clean['date'].max()
    start_of_last_month = last_date - pd.Timedelta(days=30)
    df_last_month = df_clean[df_clean['date'] >= start_of_last_month].copy()
    
    print(f"   تعداد رکوردهای ماه اخیر: {len(df_last_month):,}")
    print(f"   تعداد ناهنجاری: {df_last_month['Is_Anomaly'].sum():,}")
    
    try:
        os.makedirs(os.path.dirname(output_filename), exist_ok=True)
        df_last_month.to_excel(output_filename, index=False)
        print(f"✅ فایل ذخیره شد: {output_filename}")
        return True
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False


def analysis_lubrication_5_autoencoder_advanced(file_path, output_filename):
    """تحلیل 5: Autoencoder + EWMA + Dynamic Thresholds (روغن‌کاری)"""
    print(f"\n{'='*60}")
    print(f"🔄 [روغن‌کاری-5] Autoencoder Advanced")
    print(f"{'='*60}")
    
    all_features = ['AssetID_9343','AssetID_9375', 'AssetID_8341', 'AssetID_8342', 'AssetID_8343', 
                    'AssetID_8344', 'AssetID_8346', 'AssetID_9286', 'AssetID_9287']
    
    try:
        df = pd.read_excel(file_path)
        df['date'] = pd.to_datetime(df['date'])
        df = df.sort_values(by='date')
        print(f"✅ فایل اصلی خوانده شد. تعداد رکوردها: {len(df):,}")
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False
    
    df_clean = df.dropna(subset=all_features).copy()
    raw_data = df_clean[all_features].values
    print(f"📊 تعداد رکوردهای بدون داده خالی: {len(df_clean):,}")
    
    print("🔄 مرحله 1: نرمال‌سازی داده‌ها...")
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(raw_data)
    print(f"   ✅ نرمال‌سازی با {len(all_features)} سنسور انجام شد")
    
    print("🔄 مرحله 2: ساخت و آموزش مدل Autoencoder...")
    
    input_dim = len(all_features)
    input_layer = Input(shape=(input_dim,))
    encoded = Dense(16, activation='relu')(input_layer)
    latent = Dense(8, activation='relu')(encoded)
    decoded = Dense(16, activation='relu')(latent)
    output_layer = Dense(input_dim, activation='sigmoid')(decoded)
    
    autoencoder = Model(inputs=input_layer, outputs=output_layer)
    autoencoder.compile(optimizer=Adam(learning_rate=0.01), loss='mse')
    
    print("   🚀 یادگیری رفتار سیستماتیک سنسورها...")
    autoencoder.fit(scaled_data, scaled_data, epochs=150, batch_size=32, shuffle=True, verbose=0)
    print("   ✅ آموزش مدل با موفقیت انجام شد")
    
    print("🔄 مرحله 3: محاسبه شاخص‌های انحراف...")
    
    reconstructed = autoencoder.predict(scaled_data, verbose=0)
    mse_errors = np.mean(np.power(scaled_data - reconstructed, 2), axis=1)
    df_clean['Raw_Anomaly_Index'] = mse_errors
    
    print("🔄 مرحله 4: ارزیابی پیشرفته باقیمانده‌ها...")
    
    df_clean['Smooth_Deviation_Index'] = df_clean['Raw_Anomaly_Index'].ewm(alpha=0.1).mean()
    
    p95_threshold = df_clean['Smooth_Deviation_Index'].quantile(0.95)
    p99_threshold = df_clean['Smooth_Deviation_Index'].quantile(0.99)
    
    print(f"   📈 آستانه هشدار (زرد): {p95_threshold:.6f}")
    print(f"   🚫 آستانه بحرانی (قرمز): {p99_threshold:.6f}")
    
    def final_judgment(val):
        if val > p99_threshold:
            return "Critical (Red) - Systematic Failure"
        elif val > p95_threshold:
            return "Warning (Yellow) - Operational Drift"
        else:
            return "Normal (Green)"
    
    df_clean['Final_Status'] = df_clean['Smooth_Deviation_Index'].apply(final_judgment)
    
    print("🔄 مرحله 5: فیلتر کردن داده‌های یک ماه اخیر...")
    
    last_date = df_clean['date'].max()
    start_of_last_month = last_date - pd.Timedelta(days=30)
    df_output = df_clean[df_clean['date'] >= start_of_last_month].copy()
    
    print(f"   تعداد رکوردهای ماه اخیر: {len(df_output):,}")
    
    try:
        os.makedirs(os.path.dirname(output_filename), exist_ok=True)
        df_output.to_excel(output_filename, index=False)
        print(f"✅ فایل ذخیره شد: {output_filename}")
        return True
    except Exception as e:
        print(f"❌ خطا: {e}")
        return False


# ============================================================================
# بخش 4: تعریف تمام وظایف (Jobs) - 15 وظیفه
# ============================================================================

def get_all_jobs():
    """تعریف تمام ۱۵ وظیفه تحلیل - 3 سری × 5 تحلیل"""
    jobs = []
    
    # سری اول: بیرینگ (5 تابع)
    bearing_base = r'second_stage_inputs\G11\dsas_g11_bearings_vibration_temp_output.xlsx'
    bearing_out_base = r'outputs\G11\dsas_g11_bearings_vibration_temp_deviation_monitoring\deviation_monitoring\dsas_g11_bearings_vibration_temp_deviation_monitoring_output'
    
    jobs.extend([
        {'name': 'Bearing-1: XGBoost Wide', 'function': analysis_bearing_1_xgboost_wide,
         'file_path': bearing_base, 'output_filename': f'{bearing_out_base}1.xlsx'},
        {'name': 'Bearing-2: XGBoost Long', 'function': analysis_bearing_2_xgboost_long,
         'file_path': bearing_base, 'output_filename': f'{bearing_out_base}2.xlsx'},
        {'name': 'Bearing-3: XGBoost Refined', 'function': analysis_bearing_3_xgboost_refined,
         'file_path': bearing_base, 'output_filename': f'{bearing_out_base}3.xlsx'},
        {'name': 'Bearing-4: Autoencoder Basic', 'function': analysis_bearing_4_autoencoder_basic,
         'file_path': bearing_base, 'output_filename': f'{bearing_out_base}4.xlsx'},
        {'name': 'Bearing-5: Autoencoder Advanced', 'function': analysis_bearing_5_autoencoder_advanced,
         'file_path': bearing_base, 'output_filename': f'{bearing_out_base}5.xlsx'}
    ])
    
    # سری دوم: ژنراتور (5 تابع)
    gen_base = r'second_stage_inputs\G11\dsas_g11_generator_bearings_output.xlsx'
    gen_out_base = r'outputs\G11\dsas_g11_generator_bearings_deviation_monitoring\deviation_monitoring\dsas_g11_generator_bearings_deviation_monitoring_output'
    
    jobs.extend([
        {'name': 'Generator-1: XGBoost Wide', 'function': analysis_generator_1_xgboost_wide,
         'file_path': gen_base, 'output_filename': f'{gen_out_base}1.xlsx'},
        {'name': 'Generator-2: XGBoost Long', 'function': analysis_generator_2_xgboost_long,
         'file_path': gen_base, 'output_filename': f'{gen_out_base}2.xlsx'},
        {'name': 'Generator-3: XGBoost Refined', 'function': analysis_generator_3_xgboost_refined,
         'file_path': gen_base, 'output_filename': f'{gen_out_base}3.xlsx'},
        {'name': 'Generator-4: Autoencoder Basic', 'function': analysis_generator_4_autoencoder_basic,
         'file_path': gen_base, 'output_filename': f'{gen_out_base}4.xlsx'},
        {'name': 'Generator-5: Autoencoder Advanced', 'function': analysis_generator_5_autoencoder_advanced,
         'file_path': gen_base, 'output_filename': f'{gen_out_base}5.xlsx'}
    ])
    
    # سری سوم: روغن‌کاری (5 تابع)
    lub_base = r'second_stage_inputs\G11\dsas_g11_lubrication_system_output.xlsx'
    lub_out_base = r'outputs\G11\dsas_g11_lubrication_system_deviation_monitoring\deviation_monitoring\dsas_g11_lubrication_system_deviation_monitoring_output'
    
    jobs.extend([
        {'name': 'Lubrication-1: XGBoost Wide', 'function': analysis_lubrication_1_xgboost_wide,
         'file_path': lub_base, 'output_filename': f'{lub_out_base}1.xlsx'},
        {'name': 'Lubrication-2: XGBoost Long', 'function': analysis_lubrication_2_xgboost_long,
         'file_path': lub_base, 'output_filename': f'{lub_out_base}2.xlsx'},
        {'name': 'Lubrication-3: XGBoost Refined', 'function': analysis_lubrication_3_xgboost_refined,
         'file_path': lub_base, 'output_filename': f'{lub_out_base}3.xlsx'},
        {'name': 'Lubrication-4: Autoencoder Basic', 'function': analysis_lubrication_4_autoencoder_basic,
         'file_path': lub_base, 'output_filename': f'{lub_out_base}4.xlsx'},
        {'name': 'Lubrication-5: Autoencoder Advanced', 'function': analysis_lubrication_5_autoencoder_advanced,
         'file_path': lub_base, 'output_filename': f'{lub_out_base}5.xlsx'}
    ])
    
    return jobs


def run_all_analyses():
    """اجرای تمام ۱۵ تحلیل به ترتیب"""
    print("\n" + "="*80)
    print(f"🚀 شروع اجرای همه تحلیل‌ها (۳ سری × ۵ تحلیل = ۱۵ وظیفه)")
    print(f"📅 زمان: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print("="*80)
    print("📋 مجموعه‌ها:")
    print("   1. بیرینگ (Bearing) - ۵ تحلیل")
    print("   2. ژنراتور (Generator) - ۵ تحلیل")
    print("   3. روغن‌کاری (Lubrication) - ۵ تحلیل")
    print("="*80)
    print("📊 مجموع: ۱۵ فایل خروجی")
    print("="*80)
    
    jobs = get_all_jobs()
    results = []
    
    for i, job in enumerate(jobs, 1):
        print(f"\n{'#'*80}")
        print(f"# وظیفه {i} از {len(jobs)}: {job['name']}")
        print(f"{'#'*80}")
        
        try:
            success = job['function'](job['file_path'], job['output_filename'])
            results.append({
                'job_name': job['name'],
                'success': success,
                'timestamp': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
            })
            
            if success:
                print(f"✅ وظیفه {i} با موفقیت کامل شد")
            else:
                print(f"❌ وظیفه {i} با شکست مواجه شد")
                
        except Exception as e:
            print(f"❌ خطای غیرمنتظره در وظیفه {i}: {e}")
            results.append({
                'job_name': job['name'],
                'success': False,
                'timestamp': datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
                'error': str(e)
            })
    
    # گزارش نهایی
    print("\n" + "="*80)
    print("📊 گزارش نهایی اجرای همه تحلیل‌ها")
    print("="*80)
    
    success_count = sum(1 for r in results if r['success'])
    total_count = len(results)
    
    print(f"✅ موفق: {success_count} از {total_count}")
    print(f"❌ ناموفق: {total_count - success_count} از {total_count}")
    
    print("\n📋 جزئیات:")
    for i, r in enumerate(results, 1):
        status = "✅" if r['success'] else "❌"
        print(f"   {i:2d}. {status} {r['job_name']} - {r['timestamp']}")
    
    print("="*80)
    print(f"🏁 پایان اجرا در {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print("="*80)
    
    return results


# ============================================================================
# بخش 5: زمان‌بندی (Scheduler) با دو زمان ۹:۰۰ و ۲۱:۰۰
# ============================================================================

def run_scheduler():
    """بررسی مداوم برای اجرا در زمان‌های مشخص (هر روز ساعت ۹:۰۰ و ۲۱:۰۰)"""
    print("="*80)
    print("🔄 برنامه زمان‌بندی خودکار شروع به کار کرد")
    print("📋 شامل ۳ مجموعه (بیرینگ، ژنراتور، روغن‌کاری) × ۵ تحلیل = ۱۵ خروجی")
    print("="*80)
    print("⏰ زمان‌های اجرا (هر روز):")
    print("   - ساعت 09:00")
    print("   - ساعت 21:00")
    print("="*80)
    print("💡 برای توقف برنامه، Ctrl+C را بزنید")
    print("="*80)
    
    last_run_times = {}
    
    while True:
        try:
            now = datetime.now()
            current_time = now.strftime("%H:%M")
            
            if current_time in ["18:53", "21:00"]:
                if last_run_times.get(current_time) != now.strftime("%Y-%m-%d"):
                    print("\n" + "="*80)
                    print(f"⏰ زمان اجرا فرا رسید: {now.strftime('%Y-%m-%d %H:%M:%S')}")
                    print("="*80)
                    
                    results = run_all_analyses()
                    last_run_times[current_time] = now.strftime("%Y-%m-%d")
                    
                    print("\n" + "="*80)
                    print("✅ اجرای زمان‌بندی شده با موفقیت کامل شد!")
                    print("="*80)
                    
                    time.sleep(60)
            
            time.sleep(30)
            
        except KeyboardInterrupt:
            print("\n" + "="*80)
            print("⏹️ برنامه با دستور کاربر متوقف شد")
            print(f"⏹️ زمان توقف: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
            print("="*80)
            break
            
        except Exception as e:
            print(f"❌ خطا در حلقه اصلی: {e}")
            time.sleep(60)


# ============================================================================
# بخش 6: اجرای اصلی
# ============================================================================

if __name__ == "__main__":
    try:
        print("="*80)
        print("🚀 شروع برنامه جامع پایش انحراف (۳ سری یکپارچه)")
        print("="*80)
        print("📋 مجموعه‌ها و خروجی‌ها:")
        print("   ┌─────────────────────────────────────────────────────────┐")
        print("   │  مجموعه ۱: بیرینگ (Bearing)          → ۵ خروجی      │")
        print("   │  مجموعه ۲: ژنراتور (Generator)       → ۵ خروجی      │")
        print("   │  مجموعه ۳: روغن‌کاری (Lubrication)   → ۵ خروجی      │")
        print("   └─────────────────────────────────────────────────────────┘")
        print("   مجموع: ۱۵ فایل خروجی")
        print("="*80)
        print("⏰ زمان‌بندی: هر روز ساعت 09:00 و 21:00")
        print("="*80)
        
        run_scheduler()
        
    except Exception as e:
        print(f"❌ خطای غیرمنتظره: {e}")
        import traceback
        traceback.print_exc()
        input("برای خروج Enter بزنید...")
# Out:
# WARNING:tensorflow:From C:\Users\pishva_r\AppData\Local\Temp\ipykernel_8484\2475052662.py:20: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# ================================================================================
# 🚀 شروع برنامه جامع پایش انحراف (۳ سری یکپارچه)
# ================================================================================
# 📋 مجموعه‌ها و خروجی‌ها:
#    ┌─────────────────────────────────────────────────────────┐
#    │  مجموعه ۱: بیرینگ (Bearing)          → ۵ خروجی      │
#    │  مجموعه ۲: ژنراتور (Generator)       → ۵ خروجی      │
#    │  مجموعه ۳: روغن‌کاری (Lubrication)   → ۵ خروجی      │
#    └─────────────────────────────────────────────────────────┘
#    مجموع: ۱۵ فایل خروجی
# ================================================================================
# ⏰ زمان‌بندی: هر روز ساعت 09:00 و 21:00
# ================================================================================
# ================================================================================
# 🔄 برنامه زمان‌بندی خودکار شروع به کار کرد
# 📋 شامل ۳ مجموعه (بیرینگ، ژنراتور، روغن‌کاری) × ۵ تحلیل = ۱۵ خروجی
# ================================================================================
# ⏰ زمان‌های اجرا (هر روز):
#    - ساعت 09:00
#    - ساعت 21:00
# ================================================================================
# 💡 برای توقف برنامه، Ctrl+C را بزنید
# ================================================================================
#
# ================================================================================
# ⏰ زمان اجرا فرا رسید: 2026-07-09 18:53:08
# ================================================================================
#
# ================================================================================
# 🚀 شروع اجرای همه تحلیل‌ها (۳ سری × ۵ تحلیل = ۱۵ وظیفه)
# 📅 زمان: 2026-07-09 18:53:08
# ================================================================================
# 📋 مجموعه‌ها:
#    1. بیرینگ (Bearing) - ۵ تحلیل
#    2. ژنراتور (Generator) - ۵ تحلیل
#    3. روغن‌کاری (Lubrication) - ۵ تحلیل
# ================================================================================
# 📊 مجموع: ۱۵ فایل خروجی
# ================================================================================
#
# ################################################################################
# # وظیفه 1 از 15: Bearing-1: XGBoost Wide
# ################################################################################
#
# ============================================================
# 🔄 [بیرینگ-1] XGBoost Wide
# ============================================================
# ✅ فایل اصلی خوانده شد. تعداد رکوردها: 11,752
# 🔄 مرحله 1: پیش‌پردازش و حذف داده‌های پرت...
#    حذف 1,175 ردیف به عنوان داده‌های پرت
#    داده‌های آموزش: 8,461 رکورد
#    داده‌های تست: 2,116 رکورد
# 🔄 مرحله 2: یادگیری و پیش‌بینی برای تمام سنسورها...
#    ✅ AssetID_9358: RMSE = 9.424736
#    ✅ AssetID_9359: RMSE = 20.025093
#    ✅ AssetID_9360: RMSE = 4.691303
#    ✅ AssetID_9361: RMSE = 11.051948
# ✅ فایل ذخیره شد: outputs\G11\dsas_g11_bearings_vibration_temp_deviation_monitoring\deviation_monitoring\dsas_g11_bearings_vibration_temp_deviation_monitoring_output1.xlsx
# ✅ وظیفه 1 با موفقیت کامل شد
#
# ################################################################################
# # وظیفه 2 از 15: Bearing-2: XGBoost Long
# ################################################################################
#
# ============================================================
# 🔄 [بیرینگ-2] XGBoost Long
# ============================================================
# ✅ فایل اصلی خوانده شد. تعداد رکوردها: 11,752
# 🔄 مرحله 1: پیش‌پردازش و حذف داده‌های پرت...
#    حذف 1,175 ردیف به عنوان داده‌های پرت
#    داده‌های آموزش: 8,461 رکورد
#    داده‌های تست: 2,116 رکورد
# 🔄 مرحله 2: یادگیری و پیش‌بینی برای تمام سنسورها...
#    ✅ AssetID_9358: RMSE = 9.424736
#    ✅ AssetID_9359: RMSE = 20.025093
#    ✅ AssetID_9360: RMSE = 4.691303
#    ✅ AssetID_9361: RMSE = 11.051948
# 🔄 مرحله 3: تغییر ساختار داده به فرمت Long...
#    ✅ تعداد رکوردهای نهایی: 8,488
# ✅ فایل ذخیره شد: outputs\G11\dsas_g11_bearings_vibration_temp_deviation_monitoring\deviation_monitoring\dsas_g11_bearings_vibration_temp_deviation_monitoring_output2.xlsx
# ✅ وظیفه 2 با موفقیت کامل شد
#
# ################################################################################
# # وظیفه 3 از 15: Bearing-3: XGBoost Refined
# ################################################################################
#
# ============================================================
# 🔄 [بیرینگ-3] XGBoost Refined
# ============================================================
# ✅ فایل اصلی خوانده شد. تعداد رکوردها: 11,752
# 🔄 مرحله 1: جداسازی داده‌های آموزشی و تست...
#    داده‌های آموزشی: 11,633 رکورد
#    داده‌های تست: 119 رکورد
# 🔄 مرحله 2: پالایش داده‌های آموزشی با DBSCAN...
#    داده‌های سالم تایید شده: 10,946 رکورد
#    داده‌های پرت حذف شده: 687 ردیف
# 🔄 مرحله 3: آموزش مدل‌های XGBoost...
#    ✅ مدل برای AssetID_9357 آموزش داده شد
#    ✅ مدل برای AssetID_9343 آموزش داده شد
#    ✅ مدل برای AssetID_9358 آموزش داده شد
#    ✅ مدل برای AssetID_9359 آموزش داده شد
#    ✅ مدل برای AssetID_9360 آموزش داده شد
#    ✅ مدل برای AssetID_9361 آموزش داده شد
#    ✅ مدل برای AssetID_9368 آموزش داده شد
#    ✅ مدل برای AssetID_9369 آموزش داده شد
#    ✅ مدل برای AssetID_9370 آموزش داده شد
# 🔄 مرحله 4: پایش انحراف در داده‌های تست...
#
# 📊 تعداد ناهنجاری‌ها: 13 (10.92%)
# ✅ فایل ذخیره شد: outputs\G11\dsas_g11_bearings_vibration_temp_deviation_monitoring\deviation_monitoring\dsas_g11_bearings_vibration_temp_deviation_monitoring_output3.xlsx
# ✅ وظیفه 3 با موفقیت کامل شد
#
# ################################################################################
# # وظیفه 4 از 15: Bearing-4: Autoencoder Basic
# ################################################################################
#
# ============================================================
# 🔄 [بیرینگ-4] Autoencoder Basic
# ============================================================
# ✅ فایل اصلی خوانده شد. تعداد رکوردها: 11,752
# 📊 تعداد رکوردهای بدون داده خالی: 11,752
# 🔄 مرحله 1: نرمال‌سازی داده‌ها...
#    ✅ نرمال‌سازی با 9 سنسور انجام شد
# 🔄 مرحله 2: ساخت و آموزش مدل Autoencoder...
#    🚀 در حال یادگیری رفتار سیستم...
#    ✅ آموزش مدل با موفقیت انجام شد
# 🔄 مرحله 3: محاسبه خطای بازسازی...
#    ✅ آستانه ناهنجاری: 0.016687
# 🔄 مرحله 4: فیلتر کردن داده‌های یک ماه اخیر...
#    تعداد رکوردهای ماه اخیر: 152
#    تعداد ناهنجاری: 3
# ✅ فایل ذخیره شد: outputs\G11\dsas_g11_bearings_vibration_temp_deviation_monitoring\deviation_monitoring\dsas_g11_bearings_vibration_temp_deviation_monitoring_output4.xlsx
# ✅ وظیفه 4 با موفقیت کامل شد
#
# ################################################################################
# # وظیفه 5 از 15: Bearing-5: Autoencoder Advanced
# ################################################################################
#
# ============================================================
# 🔄 [بیرینگ-5] Autoencoder Advanced
# ============================================================
# ✅ فایل اصلی خوانده شد. تعداد رکوردها: 11,752
# 📊 تعداد رکوردهای بدون داده خالی: 11,752
# 🔄 مرحله 1: نرمال‌سازی داده‌ها...
#    ✅ نرمال‌سازی با 9 سنسور انجام شد
# 🔄 مرحله 2: ساخت و آموزش مدل Autoencoder...
#    🚀 یادگیری رفتار سیستماتیک سنسورها...
#    ✅ آموزش مدل با موفقیت انجام شد
# 🔄 مرحله 3: محاسبه شاخص‌های انحراف...
# 🔄 مرحله 4: ارزیابی پیشرفته باقیمانده‌ها...
#    📈 آستانه هشدار (زرد): 0.002742
#    🚫 آستانه بحرانی (قرمز): 0.006430
# 🔄 مرحله 5: فیلتر کردن داده‌های یک ماه اخیر...
#    تعداد رکوردهای ماه اخیر: 152
# ✅ فایل ذخیره شد: outputs\G11\dsas_g11_bearings_vibration_temp_deviation_monitoring\deviation_monitoring\dsas_g11_bearings_vibration_temp_deviation_monitoring_output5.xlsx
# ✅ وظیفه 5 با موفقیت کامل شد
#
# ################################################################################
# # وظیفه 6 از 15: Generator-1: XGBoost Wide
# ################################################################################
#
# ============================================================
# 🔄 [ژنراتور-1] XGBoost Wide
# ============================================================
# ✅ فایل اصلی خوانده شد. تعداد رکوردها: 11,915
# 🔄 مرحله 1: پیش‌پردازش و حذف داده‌های پرت...
#    حذف 1,191 ردیف به عنوان داده‌های پرت
#    داده‌های آموزش: 8,579 رکورد
#    داده‌های تست: 2,145 رکورد
# 🔄 مرحله 2: یادگیری و پیش‌بینی برای تمام سنسورها...
#    ✅ AssetID_9362: RMSE = 6.558366
#    ✅ AssetID_9363: RMSE = 4.653764
#    ✅ AssetID_9364: RMSE = 8.001394
#    ✅ AssetID_9365: RMSE = 8.369748
#    ✅ AssetID_9366: RMSE = 17.726519
#    ✅ AssetID_9367: RMSE = 16.422210
#    ✅ AssetID_9371: RMSE = 0.584440
#    ✅ AssetID_9372: RMSE = 0.702388
#    ✅ AssetID_9373: RMSE = 1.109904
# ✅ فایل ذخیره شد: outputs\G11\dsas_g11_generator_bearings_deviation_monitoring\deviation_monitoring\dsas_g11_generator_bearings_deviation_monitoring_output1.xlsx
# ✅ وظیفه 6 با موفقیت کامل شد
#
# ################################################################################
# # وظیفه 7 از 15: Generator-2: XGBoost Long
# ################################################################################
#
# ============================================================
# 🔄 [ژنراتور-2] XGBoost Long
# ============================================================
# ✅ فایل اصلی خوانده شد. تعداد رکوردها: 11,915
# 🔄 مرحله 1: پیش‌پردازش و حذف داده‌های پرت...
#    حذف 1,191 ردیف به عنوان داده‌های پرت
#    داده‌های آموزش: 8,579 رکورد
#    داده‌های تست: 2,145 رکورد
# 🔄 مرحله 2: یادگیری و پیش‌بینی برای تمام سنسورها...
#    ✅ AssetID_9362: RMSE = 6.558366
#    ✅ AssetID_9363: RMSE = 4.653764
#    ✅ AssetID_9364: RMSE = 8.001394
#    ✅ AssetID_9365: RMSE = 8.369748
#    ✅ AssetID_9366: RMSE = 17.726519
#    ✅ AssetID_9367: RMSE = 16.422210
#    ✅ AssetID_9371: RMSE = 0.584440
#    ✅ AssetID_9372: RMSE = 0.702388
#    ✅ AssetID_9373: RMSE = 1.109904
# 🔄 مرحله 3: تغییر ساختار داده به فرمت Long...
#    ✅ تعداد رکوردهای نهایی: 19,359
# ✅ فایل ذخیره شد: outputs\G11\dsas_g11_generator_bearings_deviation_monitoring\deviation_monitoring\dsas_g11_generator_bearings_deviation_monitoring_output2.xlsx
# ✅ وظیفه 7 با موفقیت کامل شد
#
# ################################################################################
# # وظیفه 8 از 15: Generator-3: XGBoost Refined
# ################################################################################
#
# ============================================================
# 🔄 [ژنراتور-3] XGBoost Refined
# ============================================================
# ✅ فایل اصلی خوانده شد. تعداد رکوردها: 11,915
# 🔄 مرحله 1: جداسازی داده‌های آموزشی و تست...
#    داده‌های آموزشی: 11,797 رکورد
#    داده‌های تست: 118 رکورد
# 🔄 مرحله 2: پالایش داده‌های آموزشی با DBSCAN...
#    داده‌های سالم تایید شده: 11,205 رکورد
#    داده‌های پرت حذف شده: 592 ردیف
# 🔄 مرحله 3: آموزش مدل‌های XGBoost...
#    ✅ مدل برای AssetID_9362 آموزش داده شد
#    ✅ مدل برای AssetID_9363 آموزش داده شد
#    ✅ مدل برای AssetID_9364 آموزش داده شد
#    ✅ مدل برای AssetID_9365 آموزش داده شد
#    ✅ مدل برای AssetID_9366 آموزش داده شد
#    ✅ مدل برای AssetID_9367 آموزش داده شد
#    ✅ مدل برای AssetID_9371 آموزش داده شد
#    ✅ مدل برای AssetID_9372 آموزش داده شد
#    ✅ مدل برای AssetID_9373 آموزش داده شد
# 🔄 مرحله 4: پایش انحراف در داده‌های تست...
#
# 📊 تعداد ناهنجاری‌ها: 3 (2.54%)
# ✅ فایل ذخیره شد: outputs\G11\dsas_g11_generator_bearings_deviation_monitoring\deviation_monitoring\dsas_g11_generator_bearings_deviation_monitoring_output3.xlsx
# ✅ وظیفه 8 با موفقیت کامل شد
#
# ################################################################################
# # وظیفه 9 از 15: Generator-4: Autoencoder Basic
# ################################################################################
#
# ============================================================
# 🔄 [ژنراتور-4] Autoencoder Basic
# ============================================================
# ✅ فایل اصلی خوانده شد. تعداد رکوردها: 11,915
# 📊 تعداد رکوردهای بدون داده خالی: 11,915
# 🔄 مرحله 1: نرمال‌سازی داده‌ها...
#    ✅ نرمال‌سازی با 9 سنسور انجام شد
# 🔄 مرحله 2: ساخت و آموزش مدل Autoencoder...
#    🚀 در حال یادگیری رفتار سیستم...
#    ✅ آموزش مدل با موفقیت انجام شد
# 🔄 مرحله 3: محاسبه خطای بازسازی...
#    ✅ آستانه ناهنجاری: 0.001353
# 🔄 مرحله 4: فیلتر کردن داده‌های یک ماه اخیر...
#    تعداد رکوردهای ماه اخیر: 178
#    تعداد ناهنجاری: 0
# ✅ فایل ذخیره شد: outputs\G11\dsas_g11_generator_bearings_deviation_monitoring\deviation_monitoring\dsas_g11_generator_bearings_deviation_monitoring_output4.xlsx
# ✅ وظیفه 9 با موفقیت کامل شد
#
# ################################################################################
# # وظیفه 10 از 15: Generator-5: Autoencoder Advanced
# ################################################################################
#
# ============================================================
# 🔄 [ژنراتور-5] Autoencoder Advanced
# ============================================================
# ✅ فایل اصلی خوانده شد. تعداد رکوردها: 11,915
# 📊 تعداد رکوردهای بدون داده خالی: 11,915
# 🔄 مرحله 1: نرمال‌سازی داده‌ها...
#    ✅ نرمال‌سازی با 9 سنسور انجام شد
# 🔄 مرحله 2: ساخت و آموزش مدل Autoencoder...
#    🚀 یادگیری رفتار سیستماتیک سنسورها...
#    ✅ آموزش مدل با موفقیت انجام شد
# 🔄 مرحله 3: محاسبه شاخص‌های انحراف...
# 🔄 مرحله 4: ارزیابی پیشرفته باقیمانده‌ها...
#    📈 آستانه هشدار (زرد): 0.004050
#    🚫 آستانه بحرانی (قرمز): 0.006218
# 🔄 مرحله 5: فیلتر کردن داده‌های یک ماه اخیر...
#    تعداد رکوردهای ماه اخیر: 178
# ✅ فایل ذخیره شد: outputs\G11\dsas_g11_generator_bearings_deviation_monitoring\deviation_monitoring\dsas_g11_generator_bearings_deviation_monitoring_output5.xlsx
# ✅ وظیفه 10 با موفقیت کامل شد
#
# ################################################################################
# # وظیفه 11 از 15: Lubrication-1: XGBoost Wide
# ################################################################################
#
# ============================================================
# 🔄 [روغن‌کاری-1] XGBoost Wide
# ============================================================
# ✅ فایل اصلی خوانده شد. تعداد رکوردها: 6,796
# 🔄 مرحله 1: پیش‌پردازش و حذف داده‌های پرت...
#    حذف 679 ردیف به عنوان داده‌های پرت
#    داده‌های آموزش: 4,893 رکورد
#    داده‌های تست: 1,224 رکورد
# 🔄 مرحله 2: یادگیری و پیش‌بینی برای تمام سنسورها...
#    ✅ AssetID_9343: RMSE = 6.954235
#    ✅ AssetID_9357: RMSE = 4.698040
#    ✅ AssetID_9375: RMSE = 1.281289
#    ✅ AssetID_8341: RMSE = 0.118287
#    ✅ AssetID_8343: RMSE = 1.087040
#    ✅ AssetID_8344: RMSE = 6.503900
#    ✅ AssetID_8346: RMSE = 0.643561
#    ✅ AssetID_9286: RMSE = 0.166489
#    ✅ AssetID_9287: RMSE = 0.090837
# ✅ فایل ذخیره شد: outputs\G11\dsas_g11_lubrication_system_deviation_monitoring\deviation_monitoring\dsas_g11_lubrication_system_deviation_monitoring_output1.xlsx
# ✅ وظیفه 11 با موفقیت کامل شد
#
# ################################################################################
# # وظیفه 12 از 15: Lubrication-2: XGBoost Long
# ################################################################################
#
# ============================================================
# 🔄 [روغن‌کاری-2] XGBoost Long
# ============================================================
# ✅ فایل اصلی خوانده شد. تعداد رکوردها: 6,796
# 🔄 مرحله 1: پیش‌پردازش و حذف داده‌های پرت...
#    حذف 679 ردیف به عنوان داده‌های پرت
#    داده‌های آموزش: 4,893 رکورد
#    داده‌های تست: 1,224 رکورد
# 🔄 مرحله 2: یادگیری و پیش‌بینی برای تمام سنسورها...
#    ✅ AssetID_9343: RMSE = 6.954235
#    ✅ AssetID_9357: RMSE = 4.698040
#    ✅ AssetID_9375: RMSE = 1.281289
#    ✅ AssetID_8341: RMSE = 0.118287
#    ✅ AssetID_8343: RMSE = 1.087040
#    ✅ AssetID_8344: RMSE = 6.503900
#    ✅ AssetID_8346: RMSE = 0.643561
#    ✅ AssetID_9286: RMSE = 0.166489
#    ✅ AssetID_9287: RMSE = 0.090837
# 🔄 مرحله 3: تغییر ساختار داده به فرمت Long...
#    ✅ تعداد رکوردهای نهایی: 11,016
# ✅ فایل ذخیره شد: outputs\G11\dsas_g11_lubrication_system_deviation_monitoring\deviation_monitoring\dsas_g11_lubrication_system_deviation_monitoring_output2.xlsx
# ✅ وظیفه 12 با موفقیت کامل شد
#
# ################################################################################
# # وظیفه 13 از 15: Lubrication-3: XGBoost Refined
# ################################################################################
#
# ============================================================
# 🔄 [روغن‌کاری-3] XGBoost Refined
# ============================================================
# ✅ فایل اصلی خوانده شد. تعداد رکوردها: 6,796
# 🔄 مرحله 1: جداسازی داده‌های آموزشی و تست...
#    داده‌های آموزشی: 6,730 رکورد
#    داده‌های تست: 66 رکورد
# 🔄 مرحله 2: پالایش داده‌های آموزشی با DBSCAN...
#    داده‌های سالم تایید شده: 6,133 رکورد
#    داده‌های پرت حذف شده: 597 ردیف
# 🔄 مرحله 3: آموزش مدل‌های XGBoost...
#    ✅ مدل برای AssetID_9343 آموزش داده شد
#    ✅ مدل برای AssetID_9375 آموزش داده شد
#    ✅ مدل برای AssetID_8341 آموزش داده شد
#    ✅ مدل برای AssetID_8342 آموزش داده شد
#    ✅ مدل برای AssetID_8343 آموزش داده شد
#    ✅ مدل برای AssetID_8344 آموزش داده شد
#    ✅ مدل برای AssetID_8346 آموزش داده شد
#    ✅ مدل برای AssetID_9286 آموزش داده شد
#    ✅ مدل برای AssetID_9287 آموزش داده شد
# 🔄 مرحله 4: پایش انحراف در داده‌های تست...
#
# 📊 تعداد ناهنجاری‌ها: 1 (1.52%)
# ✅ فایل ذخیره شد: outputs\G11\dsas_g11_lubrication_system_deviation_monitoring\deviation_monitoring\dsas_g11_lubrication_system_deviation_monitoring_output3.xlsx
# ✅ وظیفه 13 با موفقیت کامل شد
#
# ################################################################################
# # وظیفه 14 از 15: Lubrication-4: Autoencoder Basic
# ################################################################################
#
# ============================================================
# 🔄 [روغن‌کاری-4] Autoencoder Basic
# ============================================================
# ✅ فایل اصلی خوانده شد. تعداد رکوردها: 6,796
# 📊 تعداد رکوردهای بدون داده خالی: 6,796
# 🔄 مرحله 1: نرمال‌سازی داده‌ها...
#    ✅ نرمال‌سازی با 9 سنسور انجام شد
# 🔄 مرحله 2: ساخت و آموزش مدل Autoencoder...
#    🚀 در حال یادگیری رفتار سیستم...
#    ✅ آموزش مدل با موفقیت انجام شد
# 🔄 مرحله 3: محاسبه خطای بازسازی...
#    ✅ آستانه ناهنجاری: 0.006430
# 🔄 مرحله 4: فیلتر کردن داده‌های یک ماه اخیر...
#    تعداد رکوردهای ماه اخیر: 103
#    تعداد ناهنجاری: 1
# ✅ فایل ذخیره شد: outputs\G11\dsas_g11_lubrication_system_deviation_monitoring\deviation_monitoring\dsas_g11_lubrication_system_deviation_monitoring_output4.xlsx
# ✅ وظیفه 14 با موفقیت کامل شد
#
# ################################################################################
# # وظیفه 15 از 15: Lubrication-5: Autoencoder Advanced
# ################################################################################
#
# ============================================================
# 🔄 [روغن‌کاری-5] Autoencoder Advanced
# ============================================================
# ✅ فایل اصلی خوانده شد. تعداد رکوردها: 6,796
# 📊 تعداد رکوردهای بدون داده خالی: 6,796
# 🔄 مرحله 1: نرمال‌سازی داده‌ها...
#    ✅ نرمال‌سازی با 9 سنسور انجام شد
# 🔄 مرحله 2: ساخت و آموزش مدل Autoencoder...
#    🚀 یادگیری رفتار سیستماتیک سنسورها...
#    ✅ آموزش مدل با موفقیت انجام شد
# 🔄 مرحله 3: محاسبه شاخص‌های انحراف...
# 🔄 مرحله 4: ارزیابی پیشرفته باقیمانده‌ها...
#    📈 آستانه هشدار (زرد): 0.002905
#    🚫 آستانه بحرانی (قرمز): 0.005942
# 🔄 مرحله 5: فیلتر کردن داده‌های یک ماه اخیر...
#    تعداد رکوردهای ماه اخیر: 103
# ✅ فایل ذخیره شد: outputs\G11\dsas_g11_lubrication_system_deviation_monitoring\deviation_monitoring\dsas_g11_lubrication_system_deviation_monitoring_output5.xlsx
# ✅ وظیفه 15 با موفقیت کامل شد
#
# ================================================================================
# 📊 گزارش نهایی اجرای همه تحلیل‌ها
# ================================================================================
# ✅ موفق: 15 از 15
# ❌ ناموفق: 0 از 15
#
# 📋 جزئیات:
#     1. ✅ Bearing-1: XGBoost Wide - 2026-07-09 18:53:17
#     2. ✅ Bearing-2: XGBoost Long - 2026-07-09 18:53:26
#     3. ✅ Bearing-3: XGBoost Refined - 2026-07-09 18:53:34
#     4. ✅ Bearing-4: Autoencoder Basic - 2026-07-09 18:56:19
#     5. ✅ Bearing-5: Autoencoder Advanced - 2026-07-09 18:59:06
#     6. ✅ Generator-1: XGBoost Wide - 2026-07-09 18:59:17
#     7. ✅ Generator-2: XGBoost Long - 2026-07-09 18:59:29
#     8. ✅ Generator-3: XGBoost Refined - 2026-07-09 18:59:39
#     9. ✅ Generator-4: Autoencoder Basic - 2026-07-09 19:02:25
#    10. ✅ Generator-5: Autoencoder Advanced - 2026-07-09 19:05:12
#    11. ✅ Lubrication-1: XGBoost Wide - 2026-07-09 19:05:18
#    12. ✅ Lubrication-2: XGBoost Long - 2026-07-09 19:05:26
#    13. ✅ Lubrication-3: XGBoost Refined - 2026-07-09 19:05:31
#    14. ✅ Lubrication-4: Autoencoder Basic - 2026-07-09 19:07:15
#    15. ✅ Lubrication-5: Autoencoder Advanced - 2026-07-09 19:08:55
# ================================================================================
# 🏁 پایان اجرا در 2026-07-09 19:08:55
# ================================================================================
#
# ================================================================================
# ✅ اجرای زمان‌بندی شده با موفقیت کامل شد!
# ================================================================================
